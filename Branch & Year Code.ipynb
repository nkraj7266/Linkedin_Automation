# %%
import queue
import requests, time, random
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
browser = webdriver.Chrome('driver/chromedriver.exe')
browser.get('https://www.linkedin.com//uas/login')
# username = 'dwivedimahesh141@gmail.com'
# password = 'Virat0907'
# username = 'avnichhabra222@gmail.com'
# password = 'avni#222'
username = 'tnishita04@gmail.com'
password = '$iambatman'

elementID = browser.find_element(By.ID, "username")
elementID.send_keys(username)

elementID = browser.find_element(By.ID, "password")
elementID.send_keys(password)

log_in_button = browser.find_element(By.CLASS_NAME, 'login__form_action_container')
log_in_button.click()
# Out:
# C:\Users\welcom\AppData\Local\Temp\ipykernel_24196\3988869781.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('driver/chromedriver.exe')

# %%
def scrolling_func():
    SCROLL_PAUSE_TIME = 2

    #Get scroll height
    last_height = browser.execute_script("return document.body.scrollHeight")

    for i in range(3):
        # Scroll down to bottom
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        new_height = browser.execute_script(
            "return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    return 0

# %%
# error_profiles = ['/in/may-k-86595b237/', '/in/rohit-k-350265237/']
queued_profiles = ['https://www.linkedin.com/in/shiva-bachu-8137a52a',
 'https://www.linkedin.com/in/yagya-modi-5085b51a9',
 'https://www.linkedin.com/in/darxtrix',
 'https://www.linkedin.com/in/khushiagrawal',
 'https://www.linkedin.com/in/keshav-kumar-094a5710a',
 'https://www.linkedin.com/in/urishita-puri',
 'https://www.linkedin.com/in/ansh-gupta-16-04',
 'https://www.linkedin.com/in/karthikbashetty',
 'https://www.linkedin.com/in/saurabh-singh-63512a73',
 'https://www.linkedin.com/in/chandan-kumar-01447619',
 'https://www.linkedin.com/in/nikhilesh-tripathi-985b16109',
 'https://www.linkedin.com/in/apoorva--verma',
 'https://www.linkedin.com/in/samiksha-gupta-56046588',
 'https://www.linkedin.com/in/nirmal-singh-3ab16861',
 'https://www.linkedin.com/in/onetouchfinish',
 'https://www.linkedin.com/in/mchouhanofficial',
 'https://www.linkedin.com/in/prabhanshu-pandey-b05a4223',
 'https://www.linkedin.com/in/saarthak-agrawal-856112131',
 'https://www.linkedin.com/in/raghav-gupta-530479138',
 'https://www.linkedin.com/in/anuragguptanbmc',
 'https://www.linkedin.com/in/siddhant-jalan-cse14',
 'https://www.linkedin.com/in/saahil-rathi-83792515',
 'https://www.linkedin.com/in/shivam-madeshia-97bb92109',
 'https://www.linkedin.com/in/utsav-krishnan-iit-bhu',
 'https://www.linkedin.com/in/maneeshita-sharma-90281a133',
 'https://www.linkedin.com/in/divya-gupta-761b6116b',
 'https://www.linkedin.com/in/dheeraj-chittara-32a462153',
 'https://www.linkedin.com/in/tripathi-shailesh',
 'https://www.linkedin.com/in/syedwalihamza',
 'https://www.linkedin.com/in/shivamanand',
 'https://www.linkedin.com/in/raviteja-m',
 'https://www.linkedin.com/in/joshiharshal',
 'https://www.linkedin.com/in/lukwhostalking',
 'https://www.linkedin.com/in/avinash-shah-90175723b']

# %%
names_list = []
branches_list = []
years_list = []

# %%
for link in queued_profiles:
    #link_1 = 'https://www.linkedin.com' + link
    browser.get(link)

    scrolling_func()

    soup = BeautifulSoup(browser.page_source)
    pav_2 = soup.find('h1', {'class': 'text-heading-xlarge inline t-24 v-align-middle break-words'})
    name = pav_2.get_text().strip()

    names_list.append(name)

    pav_2 = soup.findAll('section', {'class':'artdeco-card ember-view relative break-words pb3 mt2'})

    i = 0
    a = 0

    check_soup = soup.find('div', {'id': 'education'})

    for pav_check in pav_2:
        pav_check_1 = pav_2[i].find('div', {'id': 'education'})
        if(pav_check_1 == check_soup):
            a = i
        i = i+1

    cos1 = pav_2[a].find('span', {'class': 't-14 t-normal'})
    cos3 = pav_2[a].find('span', {'class': 't-14 t-normal t-black--light'})
    
    if(str(type(cos1)) == "<class 'NoneType'>"):
        branch = 'Not Given'
    else:
        cos2 = cos1.find('span', {'class': 'visually-hidden'})
        branch = cos2.get_text().strip()
        
    if(str(type(cos3)) == "<class 'NoneType'>"):
        year = 'Not Given'
    else:
        cos4 = cos3.find('span', {'class': 'visually-hidden'})
        year = cos4.get_text().strip()
    
    branches_list.append(branch)  
    years_list.append(year)

    print(name)
    print(year)
    print(branch)
# Out:
# Prayas Jain
# 2014 - 2018
# Bachelor of Technology - BTech with Honours in AI/CV, Computer Science
# Ayushi Sneha
# 2016 - 2020
# Bachelor of Technology, Computer Science and Engineering
# Dipanshu Singh
# 2016 - 2020
# Bachelor of Technology, Computer Science & Engineering
# Akshal Sharma
# 2015 - 2019
# Bachelor of Technology - BTech, Computer Science and Engineering
# Lavjeet Gangwani
# 2015 - 2019
# Bachelor of Technology, Computer Science
# Siddharth Sahay
# 2016 - 2021
# Bachelor of Technology, Computer Science and Engineering
# Manu Agrawal
# 2013 - 2017
# Bachelor's Degree, Computer Science and Engineering | Institute Rank 1| Gold Medalist
# Ronak Garg
# 2014 - 2018
# Bachelor of Technology (BTech), Electrical Engineering
# Parag Goyal
# 2011 - 2016
# Not Given
# Deepanshu Shah
# 2012 - 2016
# Bachelor of Technology (B.Tech.), Electronics Engineering
# Ayushman Singh
# 2016 - 2020
# Bachelor of Technology - BTech, Mechanical Engineering
# Pratiksha Pandey
# 2018 - 2022
# ...

# %%
del names_list[:]
del years_list[:]
del branches_list[:]

# %%
print(names_list)
print(years_list)
print(branches_list)
# Out:
# []
# []
# []

# %%
for item in branches_list:
    print(item)

# %%
for item in years_list:
    print(item)
